# %%
# 소상공인 상가업소 정보 서비스 
# https://www.data.go.kr/iim/api/selectAPIAcountView.do

# %%
api_key = 'uUo9EnUtUrjdfPQcrbXnpH0HMz6GhMbH3DSH7NMMnDwDk%2FiwKMCKZ0sCzZgxpXw8BtqRGz93fq8e%2B8qq6%2FiFqA%3D%3D'

# %%
import urllib.request

# %%
#url00 ='http://apis.data.go.kr/B553077/api/open/sdsc/storeListInDong?divId=ctprvnCd&key=11&ServiceKey=uUo9EnUtUrjdfPQcrbXnpH0HMz6GhMbH3DSH7NMMnDwDk%2FiwKMCKZ0sCzZgxpXw8BtqRGz93fq8e%2B8qq6%2FiFqA%3D%3D'

# %%
# url01 = http://apis.data.go.kr/B553077/api/open/sdsc/storeZoneOne?key=573&ServiceKey=uUo9EnUtUrjdfPQcrbXnpH0HMz6GhMbH3DSH7NMMnDwDk%2FiwKMCKZ0sCzZgxpXw8BtqRGz93fq8e%2B8qq6%2FiFqA%3D%3D

# %%
http://apis.data.go.kr/B553077/api/open/sdsc/storeZoneInRadius?radius=500&cx=127.004528&cy=37.567538&ServiceKey=uUo9EnUtUrjdfPQcrbXnpH0HMz6GhMbH3DSH7NMMnDwDk%2FiwKMCKZ0sCzZgxpXw8BtqRGz93fq8e%2B8qq6%2FiFqA%3D%3D

# %%
url = 'http://apis.data.go.kr/B553077/api/open/sdsc/storeListInDong?divId=ctprvnCd&key=11&ServiceKey='+api_key+'&type=json'

# %%
url

# %%
#-*- coding:utf-8 -*-
url = 'http://apis.data.go.kr/B553077/api/open/sdsc/storeListInDong?divId=ctprvnCd&key=11&ServiceKey='+api_key+'&type=json'

# %%
url
# Out:
# 'http://apis.data.go.kr/B553077/api/open/sdsc/storeListInDong?divId=ctprvnCd&key=11&ServiceKey=uUo9EnUtUrjdfPQcrbXnpH0HMz6GhMbH3DSH7NMMnDwDk%2FiwKMCKZ0sCzZgxpXw8BtqRGz93fq8e%2B8qq6%2FiFqA%3D%3D&type=json'

# %%
response = urllib.request.urlopen(url)

# %%
response

# %%
json_str = response.read().decode("utf-8")

# %%
json_str
# Out:
# '{\n\t"header" : {\n\t\t"description" : "소상공인시장진흥공단 행정동별 상가업소정보"\n\t\t,"columns" : ["상가업소번호","상호명","지점명","상권업종대분류코드","상권업종대분류명","상권업종중분류코드","상권업종중분류명","상권업종소분류코드","상권업종소분류명","표준산업분류코드","표준산업분류명","시도코드","시도명","시군구코드","시군구명","행정동코드","행정동명","법정동코드","법정동명","PNU코드","대지구분코드","대지구분명","지번본번지","지번부번지","지번주소","도로명코드","도로명","건물본번지","건물부번지","건물관리번호","건물명","도로명주소","구우편번호","신우편번호","동정보","층정보","호정보","경도","위도"]\n\t\t,"stdrYm" : "202103"\n\t\t,"resultCode" : "00"\n\t\t,"resultMsg" : "NORMAL SERVICE"\n\t},\n\t"body" : {\n\t\t\t"items" : [\n\t\t\t\t{\n\t\t\t\t"bizesId" : "10004623"\n\t\t\t\t,"bizesNm" : "이철헤어커커"\n\t\t\t\t,"brchNm" : "상계역점"\n\t\t\t\t,"indsLclsCd" : "F"\n\t\t\t\t,"indsLclsNm" : "생활서비스"\n\t\t\t\t,"indsMclsCd" : "F01"\n\t\t\t\t,"indsMclsNm" : "이/미용/건강"\n\t\t\t\t,"indsSclsCd" : "F01A01"\n\t\t\t\t,"indsSclsNm" : "여성미용실"\n\t\t\t\t,"ksicCd" : "S96112"\n\t\t\t\t,"ksicNm" : "두발미용업"\n\t\t\t\t,"ctprvnCd" : "11"\n\t\t\t\t,"ctprvnNm" : "서울특별시"\n\t\t\t\t,"signguCd" : "11350"\n\t\t\t\t,"signguNm" : "노
# ...

# %%
# json을 import 하여 문자열 -> json으로 변환

# %%
import json
json_object = json.loads(json_str)

# %%
json_object
# Out:
# {'header': {'description': '소상공인시장진흥공단 행정동별 상가업소정보',
#   'columns': ['상가업소번호',
#    '상호명',
#    '지점명',
#    '상권업종대분류코드',
#    '상권업종대분류명',
#    '상권업종중분류코드',
#    '상권업종중분류명',
#    '상권업종소분류코드',
#    '상권업종소분류명',
#    '표준산업분류코드',
#    '표준산업분류명',
#    '시도코드',
#    '시도명',
#    '시군구코드',
#    '시군구명',
#    '행정동코드',
#    '행정동명',
#    '법정동코드',
#    '법정동명',
#    'PNU코드',
#    '대지구분코드',
#    '대지구분명',
#    '지번본번지',
#    '지번부번지',
#    '지번주소',
#    '도로명코드',
#    '도로명',
#    '건물본번지',
#    '건물부번지',
#    '건물관리번호',
#    '건물명',
#    '도로명주소',
#    '구우편번호',
#    '신우편번호',
#    '동정보',
#    '층정보',
#    '호정보',
#    '경도',
#    '위도'],
#   'stdrYm': '202103',
#   'resultCode': '00',
#   'resultMsg': 'NORMAL SERVICE'},
#  'body': {'items': [{'bizesId': '10004623',
#     'bizesNm': '이철헤어커커',
#     'brchNm': '상계역점',
#     'indsLclsCd': 'F',
#     'indsLclsNm': '생활서비스',
#     'indsMclsCd': 'F01',
#     'indsMclsNm': '이/미용/건강',
#     'indsSclsCd': 'F01A01',
#     'indsSclsNm': '여성미용실',
#     'ksicCd': 'S96112',
# ...

# %%
# pandas를 이용해 json을 DataFrame 형태로
# 데이터를 보면 header와 body가 나뉜다. 우리가 필요한 정보는 body이니 그쪽 정보를 로드해서 pandas로 변형

# %%
import pandas as pd
from pandas.io.json import json_normalize

# %%
body = [json_object['body']['items']]

# %%
### 데이터 타입을 만들기 위해서는 ? [list]

# %%
df = pd.DataFrame(body)

# %%
df.to_csv('smb.csv')

# %%
df[0]
# Out:
# 0    {'bizesId': '10004623', 'bizesNm': '이철헤어커커', '...
# Name: 0, dtype: object

# %%
url00 = http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsLclsCd&key=Q&ServiceKey
# Out:
#   File "<ipython-input-22-0963ee48428d>", line 1
#     url00 = http://apis.data.go.kr/B553077/api/open/sdsc/storeListInUpjong?divId=indsLclsCd&key=Q&ServiceKey
#                 ^
# SyntaxError: invalid syntax

# %%
url00

# %%
json_str = response.read().decode("utf-8")

# %%
import json
json_object = json.loads(json_str)

# %%
#json_object

# %%
body = [json_object['body']['items']]

# %%
df = pd.DataFrame(body)

# %%
df.head()
